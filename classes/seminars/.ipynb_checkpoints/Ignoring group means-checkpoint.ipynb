# %%
n <- 42
id <- seq(1, 42)
gender <- 1 * (id <= 16) # 1 = male
pose <- (1 * (id <= 8)) + (1 * ((16 < id) & (id <= 29))) # 1 = high

# %%
require(plotrix)

plot.1 <- function(testosterone.change) {
    model <- lm(testosterone.change ~ pose*gender)
    print(summary(model))
    plot(testosterone.change ~ pose, col=c("red", "blue")[gender + 1])
    abline(coefficients(model)[1], coefficients(model)[2], col="red")
    abline(coefficients(model)[1] + coefficients(model)[3], coefficients(model)[2] + coefficients(model)[4], col="blue")
}

plot.n <- function(testosterone.change, true.change) {
    trials <- 1:dim(testosterone.change)[2]
    y <- sapply(trials, function(trial) {
        model <- lm(testosterone.change[,trial] ~ pose*gender)
        coefficients(model)["pose"]
    })
    ci <- sapply(trials, function(trial) {
        model <- lm(testosterone.change[,trial] ~ pose*gender)
        confint(model, "pose")
    })
    plotCI(x=trials, y=y, li=ci[1,], ui=ci[2,])
    abline(mean(y), 0, col="black")
    y <- sapply(trials, function(trial) {
        model <- lm(testosterone.change[,trial] ~ pose*gender)
        coefficients(model)["pose:gender"]
    })
    ci <- sapply(trials, function(trial) {
        model <- lm(testosterone.change[,trial] ~ pose*gender)
        confint(model, "pose:gender")
    })
    plotCI(x=trials, y=y, li=ci[1,], ui=ci[2,])
    abline(mean(y), 0, col="black")
}

plot.both <- function(testosterone.change, true.change) {
#     plot.1(testosterone.change[,1])
    plot.n(testosterone.change)
}

# %%
# same change, regardless of gender
plot.both(sapply(1:50, function(trial) { 
    -4 + 12*pose + rnorm(n,0,4) 
}))
# Out:
# Call:
# lm(formula = testosterone.change ~ pose * gender)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.0801  -2.7011   0.1014   3.0500   8.0143
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -3.9347     1.2494  -3.149  0.00318 **
# pose         12.2372     1.7669   6.926  3.1e-08 ***
# gender       -0.4369     2.0243  -0.216  0.83026
# pose:gender   0.5236     2.8628   0.183  0.85584
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.505 on 38 degrees of freedom
# Multiple R-squared:  0.6782,	Adjusted R-squared:  0.6528
# F-statistic: 26.69 on 3 and 38 DF,  p-value: 1.844e-09
# plot without title
# plot without title
# plot without title

# %%
# higher effect for male
plot.both(sapply(1:50, function(trial) { 
    -4 + 12*pose + 8*gender*pose + rnorm(n,0,4) 
}))
# Out:
# Call:
# lm(formula = testosterone.change ~ pose * gender)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.5254 -2.2429  0.3727  2.9657  7.8701
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -3.6077     1.2129  -2.974  0.00508 **
# pose         10.7387     1.7153   6.260  2.5e-07 ***
# gender       -0.8495     1.9651  -0.432  0.66798
# pose:gender   9.2762     2.7791   3.338  0.00190 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.373 on 38 degrees of freedom
# Multiple R-squared:  0.7744,	Adjusted R-squared:  0.7565
# F-statistic: 43.47 on 3 and 38 DF,  p-value: 2.305e-12
# plot without title
# plot without title
# plot without title

# %%
# higher variance for male
plot.both(sapply(1:50, function(trial) { 
    -4 + 12*pose + rnorm(n,0,4+8*gender) 
}))
# Out:
# Call:
# lm(formula = testosterone.change ~ pose * gender)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -22.0810  -4.1077  -0.6156   5.5682  19.0160
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -4.810      2.237  -2.150   0.0380 *
# pose          14.486      3.164   4.579  4.9e-05 ***
# gender         4.364      3.624   1.204   0.2360
# pose:gender  -13.141      5.126  -2.564   0.0144 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.066 on 38 degrees of freedom
# Multiple R-squared:  0.3648,	Adjusted R-squared:  0.3146
# F-statistic: 7.273 on 3 and 38 DF,  p-value: 0.0005688
# plot without title
# plot without title
# plot without title

# %%
# higher variance and higher mean for male
plot.both(sapply(1:50, function(trial) { 
    -4 + 12*pose + 8*pose*gender + rnorm(n,0,4+8*gender) 
}))
# Out:
# Call:
# lm(formula = testosterone.change ~ pose * gender)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.4826  -4.0492   0.3705   2.9914  29.3658
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -3.2054     2.6540  -1.208  0.23460
# pose         10.6882     3.7533   2.848  0.00707 **
# gender        0.4468     4.2999   0.104  0.91779
# pose:gender   8.7398     6.0810   1.437  0.15884
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.569 on 38 degrees of freedom
# Multiple R-squared:  0.4163,	Adjusted R-squared:  0.3703
# F-statistic: 9.036 on 3 and 38 DF,  p-value: 0.0001206
# plot without title
# plot without title
# plot without title
